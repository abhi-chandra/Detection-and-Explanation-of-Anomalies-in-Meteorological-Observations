# %% [markdown]
# # Rule Extraction for Unsupervised Outlier Detection
#
# Example of usage of a library that wrapping an unsupervised outlier detection algorithm (OneClassSVM) of scikit-learn [1] it can infer rules that are comprehensible for human beings, so the'll be able to easily understand why an specific data point is labeled as an outlier, using to do so a method called SVM+Prototypes [2] as described in [3]. To show it's capabilities the outlier analysis is applied on the student's performance dataset [4]

# %%
# Libraries
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import os
import sys
from lib.unsupervised_rules import ocsvm_rule_extractor

# %%
pip install numpy
# Out:
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\abhil\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\abhil\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\abhil\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\abhil\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\abhil\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\abhil\anaconda3\lib\site-packages)

# %%
pip install numpy==1.15.0 pandas==0.23.0 scipy==1.1.0 scikit-learn==0.19.1
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.  Using cached numpy-1.15.0.zip (4.5 MB)
# ...
#   Using cached pandas-0.23.0.tar.gz (13.1 MB)
# ...
#   Using cached scipy-1.1.0.tar.gz (15.6 MB)
# ...
#   Using cached scikit-learn-0.19.1.tar.gz (9.5 MB)
#
# ...
# WARNING: Ignoring invalid distribution -umpy (c:\users\abhil\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -umpy (c:\users\abhil\anaconda3\lib\site-packages)
#   ERROR: Command errored out with exit status 1:
# ...

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd

data = pd.read_csv("test_set_colab.csv")  

numeric_attributes = ['tmpc', 'dwpc','relh', 'drct', 'wspeedkm','pressure','vsbykm', 'feelc']

x=data[numeric_attributes]

# %%
dct_params = {'nu':0.1, 'kernel':"rbf", 'gamma':0.1}

# %%
_, df_result = ocsvm_rule_extractor(x, numeric_attributes, [], dct_params)
# Out:
# Iteration 1 | nº clusters used 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [8], in <cell line: 1>()
# ----> 1 _, df_result = ocsvm_rule_extractor(x, numeric_attributes, [], dct_params)
#
# File g:\IMP4\AlbertoBarbado-unsupervised-outlier-transparency-3c6e379\lib\unsupervised_rules.py:256, in ocsvm_rule_extractor(dataset_mat, numerical_cols, categorical_cols, dct_params)
#     252 # Case 1: Only numerical variables
#     253 if len(categorical_cols) == 0:
#     254
#     255     # Obtain rules
# --> 256     df_bounds = obtain_rules(df_anomalies_no, df_anomalies_yes, X_train, sc, n_vertex_numerical, numerical_cols)
#     258     # Extract rules
#     259     list_rules_total = []
#
# ...

# %%
df_result
# Out:
# [  tmpc_max dwpc_max relh_max drct_max wspeedkm_max pressure_max vsbykm_max  \
#  0     16.0     15.0    100.0    200.0       12.964  102302.8419   1.995582
#
#    feelc_max tmpc_min dwpc_min relh_min drct_min wspeedkm_min pressure_min  \
#  0      16.0     11.0      8.0    71.81      0.0        1.852  101693.2917
#
#    vsbykm_min feelc_min
#  0   0.046817      11.0  ,
#    tmpc_max dwpc_max relh_max drct_max wspeedkm_max pressure_max vsbykm_max  \
#  0     31.0     20.0    61.81    350.0       12.964  101388.5166   4.045633
#
#     feelc_max tmpc_min dwpc_min relh_min    drct_min wspeedkm_min pressure_min  \
#  0  31.894444     25.0     12.0     39.3  166.666667        3.704  100812.8303
#
#    vsbykm_min feelc_min
#  0   1.924311      25.0  ,
#    tmpc_max dwpc_max relh_max drct_max wspeedkm_max pressure_max vsbykm_max  \
#  0     22.0     19.0    93.97    350.0       11.112  101388.5166   4.007257
#
#    feelc_max tmpc_min dwpc_min relh_min drct_min wspeedkm_min pressure_min  \
# ...

# %% [markdown]
# ### References
#
# [1] https://scikit-learn.org/stable/modules/generated/sklearn.svm.OneClassSVM.html
#
# [2] H. Núñez, C. Angulo, and A. Català. Rule extraction from support vector machines. In *European Symposium on Artificial Neural Networks (ESANN)*, pages 107–112, 2002.
#
# [3] D. Martens, J. Huysmans, R. Setiono, J. Vanthienen, and B. Baesens. Rule Extraction from Support Vector Machines: An Overview of Issues and Application in Credit Scoring. 2008. https://pdfs.semanticscholar.org/f4d6/25688d0bd8b73cbc61454c1b701385bea214.pdf
#
# [4] https://archive.ics.uci.edu/ml/datasets/student+performance

# %%
import pandas as pd

# Define all the rules

# Define all the rules
rules = ([
    {
        "subgroup": 1,
        "conditions": {
            "tmpc": {"max": 16.0, "min": 11.0},
            "dwpc": {"max": 15.0, "min": 8.0},
            "relh": {"max": 100.0, "min": 71.81},
            "drct": {"max": 200.0, "min": 0.0},
            "wspeedkm": {"max": 12.964, "min": 1.852},
            "pressure": {"max": 102302.8419, "min": 101693.2917},
            "vsbykm": {"max": 1.9955816, "min": 0.046817164},
            "feelc": {"max": 16.0, "min": 11.0}
        }
    },
    {
        "subgroup": 2,
        "conditions": {
            "tmpc": {"max": 31.0, "min": 25.0},
            "dwpc": {"max": 20.0, "min": 12.0},
            "relh": {"max": 61.81, "min": 39.3},
            "drct": {"max": 350.0, "min": 166.6666667},
            "wspeedkm": {"max": 12.964, "min": 3.704},
            "pressure": {"max": 101388.5166, "min": 100812.8303},
            "vsbykm": {"max": 4.045633169, "min": 1.924310829},
            "feelc": {"max": 31.89444444, "min": 25.0}
        }
    },
    {
        "subgroup": 3,
        "conditions": {
            "tmpc": {"max": 22.0, "min": 15.0},
            "dwpc": {"max": 19.0, "min": 13.0},
            "relh": {"max": 93.97, "min": 72.74},
            "drct": {"max": 350.0, "min": 135.0},
            "wspeedkm": {"max": 11.112, "min": 3.704},
            "pressure": {"max": 101388.5166, "min": 100711.2386},
            "vsbykm": {"max": 4.0072566, "min": 1.4966862},
            "feelc": {"max": 22.0, "min": 15.0}
        }
    },
    {
        "subgroup": 4,
        "conditions": {
            "tmpc": {"max": 15.0, "min": 10.0},
            "dwpc": {"max": 13.0, "min": 8.0},
            "relh": {"max": 100.0, "min": 76.66},
            "drct": {"max": 340.0, "min": 137.1428571},
            "wspeedkm": {"max": 11.112, "min": 1.234666667},
            "pressure": {"max": 102302.8419, "min": 101794.8834},
            "vsbykm": {"max": 1.9955816, "min": 0.1931208},
            "feelc": {"max": 15.0, "min": 9.133333333}
        }
    },
    {
        "subgroup": 5,
        "conditions": {
            "tmpc": {"max": 21.0, "min": 15.0},
            "dwpc": {"max": 19.0, "min": 13.0},
            "relh": {"max": 100.0, "min": 72.74},
            "drct": {"max": 173.3333333, "min": 0.0},
            "wspeedkm": {"max": 5.556, "min": 0.0},
            "pressure": {"max": 101388.5166, "min": 100914.422},
            "vsbykm": {"max": 1.8024608, "min": 0.1931208},
            "feelc": {"max": 21.0, "min": 15.0}
        }
    },
    {
        "subgroup": 6,
        "conditions": {
            "tmpc": {"max": 25.0, "min": 18.0},
            "dwpc": {"max": 15.0, "min": 10.0},
            "relh": {"max": 68.39, "min": 43.97},
            "drct": {"max": 160.0, "min": 0.0},
            "wspeedkm": {"max": 4.321333333, "min": 0.0},
            "pressure": {"max": 101591.7, "min": 101083.7415},
            "vsbykm": {"max": 2.9933724, "min": 0.9977908},
            "feelc": {"max": 25.0, "min": 18.0}
        }
    },
    {
        "subgroup": 7,
        "conditions": {
            "tmpc": {"max": 16.0, "min": 11.0},
            "dwpc": {"max": 14.0, "min": 10.0},
            "relh": {"max": 100.0, "min": 76.82},
            "drct": {"max": 186.6666667, "min": 0.0},
            "wspeedkm": {"max": 7.408, "min": 1.234666667},
            "pressure": {"max": 101794.8834, "min": 101388.5166},
            "vsbykm": {"max": 2.494477, "min": 0.5954558},
            "feelc": {"max": 16.0, "min": 11.0}
        }
    },
    {
        "subgroup": 8,
        "conditions": {
            "tmpc": {"max": 11.0, "min": 5.0},
            "dwpc": {"max": 8.5, "min": 4.0},
            "relh": {"max": 100.0, "min": 73.815},
            "drct": {"max": 67.5, "min": 0.0},
            "wspeedkm": {"max": 5.556, "min": 0.0},
            "pressure": {"max": 101744.0876, "min": 101286.9249},
            "vsbykm": {"max": 1.4966862, "min": 0.0482802},
            "feelc": {"max": 11.0, "min": 5.0}
        }
    },
    {
        "subgroup": 9,
        "conditions": {
            "tmpc": {"max": 19.0, "min": 12.75},
            "dwpc": {"max": 13.0, "min": 6.0},
            "relh": {"max": 79.74, "min": 51.72},
            "drct": {"max": 360.0, "min": 80.0},
            "wspeedkm": {"max": 11.112, "min": 1.852},
            "pressure": {"max": 102099.6585, "min": 101464.7104},
            "vsbykm": {"max": 2.494477, "min": 0.80467},
            "feelc": {"max": 19.0, "min": 12.75}
        }
    },
    {
        "subgroup": 10,
        "conditions": {
            "tmpc": {"max": 24.0, "min": 19.0},
            "dwpc": {"max": 20.25, "min": 15.0},
            "relh": {"max": 94.01, "min": 64.69},
            "drct": {"max": 280.0, "min": 20.0},
            "wspeedkm": {"max": 9.26, "min": 2.778},
            "pressure": {"max": 101998.0668, "min": 101388.5166},
            "vsbykm": {"max": 2.2450293, "min": 0.80467},
            "feelc": {"max": 24.0, "min": 19.0}
        }
    },

    {
        "subgroup": 11,
        "conditions": {
            "tmpc": {"max": 16.0, "min": 11.0},
            "dwpc": {"max": 15.0, "min": 10.0},
            "relh": {"max": 100.0, "min": 81.99},
            "drct": {"max": 360.0, "min": 174.0},
            "wspeedkm": {"max": 8.334, "min": 3.704},
            "pressure": {"max": 101896.4751, "min": 101490.1083},
            "vsbykm": {"max": 1.9955816, "min": 0.0965604},
            "feelc": {"max": 16.0, "min": 11.0}
        }
    },
    {
        "subgroup": 12,
        "conditions": {
            "tmpc": {"max": 26.0, "min": 19.0},
            "dwpc": {"max": 16.0, "min": 10.0},
            "relh": {"max": 68.75, "min": 41.14},
            "drct": {"max": 360.0, "min": 145.0},
            "wspeedkm": {"max": 12.964, "min": 3.704},
            "pressure": {"max": 102099.6585, "min": 101566.3021},
            "vsbykm": {"max": 2.9933724, "min": 1.207005},
            "feelc": {"max": 26.0, "min": 19.0}
        }
    },
    {
        "subgroup": 13,
        "conditions": {
            "tmpc": {"max": 14.0, "min": 8.0},
            "dwpc": {"max": 12.0, "min": 7.0},
            "relh": {"max": 100.0, "min": 76.5},
            "drct": {"max": 330.0, "min": 186.6666667},
            "wspeedkm": {"max": 12.964, "min": 1.852},
            "pressure": {"max": 101591.7, "min": 101083.7415},
            "vsbykm": {"max": 1.9955816, "min": 0.0482802},
            "feelc": {"max": 14.0, "min": 7.305555556}
        }
    },
    {
        "subgroup": 14,
        "conditions": {
            "tmpc": {"max": 29.0, "min": 23.0},
            "dwpc": {"max": 16.0, "min": 10.0},
            "relh": {"max": 57.12, "min": 34.69},
            "drct": {"max": 360.0, "min": 240.0},
            "wspeedkm": {"max": 11.112, "min": 3.704},
            "pressure": {"max": 101896.4751, "min": 101185.3332},
            "vsbykm": {"max": 4.0072566, "min": 1.4966862},
            "feelc": {"max": 28.84444444, "min": 23.0}
        }
    },
    {
        "subgroup": 15,
        "conditions": {
            "tmpc": {"max": 12.0, "min": 7.0},
            "dwpc": {"max": 11.0, "min": 5.0},
            "relh": {"max": 100.0, "min": 71.45},
            "drct": {"max": 360.0, "min": 192.0},
            "wspeedkm": {"max": 11.112, "min": 3.704},
            "pressure": {"max": 101998.0668, "min": 101490.1083},
            "vsbykm": {"max": 1.207005, "min": 0.0482802},
            "feelc": {"max": 12.0, "min": 5.627777778}
        }
    },
    {
        "subgroup": 16,
        "conditions": {
            "tmpc": {"max": 17.0, "min": 12.0},
            "dwpc": {"max": 16.0, "min": 11.0},
            "relh": {"max": 100.0, "min": 82.12},
            "drct": {"max": 62.5, "min": 0.0},
            "wspeedkm": {"max": 3.704, "min": 0.0},
            "pressure": {"max": 101693.2917, "min": 101286.9249},
            "vsbykm": {"max": 1.3035654, "min": 0.0482802},
            "feelc": {"max": 17.0, "min": 12.0}
        }
    },
    {
        "subgroup": 17,
        "conditions": {
            "tmpc": {"max": 29.0, "min": 24.0},
            "dwpc": {"max": 20.2, "min": 13.0},
            "relh": {"max": 65.54, "min": 45.07},
            "drct": {"max": 224.0, "min": 0.0},
            "wspeedkm": {"max": 7.408, "min": 0.0},
            "pressure": {"max": 101591.7, "min": 101016.0137},
            "vsbykm": {"max": 4.506152, "min": 2.9933724},
            "feelc": {"max": 29.83888889, "min": 24.0}
        }
    },
    {
        "subgroup": 18,
        "conditions": {
            "tmpc": {"max": 21.0, "min": 15.0},
            "dwpc": {"max": 17.0, "min": 10.0},
            "relh": {"max": 93.88, "min": 63.38},
            "drct": {"max": 145.0, "min": 0.0},
            "wspeedkm": {"max": 3.704, "min": 0.0},
            "pressure": {"max": 101693.2917, "min": 101016.0137},
            "vsbykm": {"max": 4.0072566, "min": 2.494477},
            "feelc": {"max": 21.0, "min": 15.0}
        }
    },
    {
        "subgroup": 19,
        "conditions": {
            "tmpc": {"max": 26.0, "min": 19.5},
            "dwpc": {"max": 21.0, "min": 15.0},
            "relh": {"max": 88.43, "min": 60.9},
            "drct": {"max": 360.0, "min": 200.0},
            "wspeedkm": {"max": 16.668, "min": 3.704},
            "pressure": {"max": 101794.8834, "min": 101286.9249},
            "vsbykm": {"max": 2.9933724, "min": 0.9977908},
            "feelc": {"max": 26.0, "min": 19.5}
        }
    },
    {
        "subgroup": 20,
        "conditions": {
            "tmpc": {"max": 18.0, "min": 12.0},
            "dwpc": {"max": 13.0, "min": 7.0},
            "relh": {"max": 93.65, "min": 55.37},
            "drct": {"max": 200.0, "min": 0.0},
            "wspeedkm": {"max": 3.704, "min": 0.0},
            "pressure": {"max": 101998.0668, "min": 101388.5166},
            "vsbykm": {"max": 3.4922678, "min": 0.9977908},
            "feelc": {"max": 18.0, "min": 12.0}
        }
    },
    {
        "subgroup": 21,
        "conditions": {
            "tmpc": {"max": 23.0, "min": 18.0},
            "dwpc": {"max": 21.0, "min": 16.0},
            "relh": {"max": 100.0, "min": 77.9},
            "drct": {"max": 150.0, "min": 0.0},
            "wspeedkm": {"max": 3.704, "min": 0.0},
            "pressure": {"max": 101591.7, "min": 101016.0137},
            "vsbykm": {"max": 2.9933724, "min": 1.207005},
            "feelc": {"max": 23.0, "min": 18.0}
        }
    },
    {
        "subgroup": 22,
        "conditions": {
            "tmpc": {"max": 29.0, "min": 23.0},
            "dwpc": {"max": 20.0, "min": 13.0},
            "relh": {"max": 69.33, "min": 44.52},
            "drct": {"max": 70.0, "min": 0.0},
            "wspeedkm": {"max": 3.704, "min": 0.0},
            "pressure": {"max": 101794.8834, "min": 101185.3332},
            "vsbykm": {"max": 2.9933724, "min": 0.9977908},
            "feelc": {"max": 29.23888889, "min": 23.0}
        }
    },
    {
        "subgroup": 23,
        "conditions": {
            "tmpc": {"max": 10.0, "min": 5.0},
            "dwpc": {"max": 8.5, "min": 3.0},
            "relh": {"max": 100.0, "min": 71.07},
            "drct": {"max": 148.5714286, "min": 0.0},
            "wspeedkm": {"max": 8.334, "min": 0.0},
            "pressure": {"max": 102201.2502, "min": 101693.2917},
            "vsbykm": {"max": 1.4966862, "min": 0.0482802},
            "feelc": {"max": 10.0, "min": 4.719444444}
        }
    },
    {
        "subgroup": 24,
        "conditions": {
            "tmpc": {"max": 26.0, "min": 20.0},
            "dwpc": {"max": 18.5, "min": 13.0},
            "relh": {"max": 73.44, "min": 50.17},
            "drct": {"max": 200.0, "min": 0.0},
            "wspeedkm": {"max": 7.408, "min": 1.852},
            "pressure": {"max": 101490.1083, "min": 100914.422},
            "vsbykm": {"max": 2.9933724, "min": 0.9977908},
            "feelc": {"max": 26.0, "min": 20.0}
        }
    },
    {
        "subgroup": 25,
        "conditions": {
            "tmpc": {"max": 20.0, "min": 14.0},
            "dwpc": {"max": 18.0, "min": 12.66666667},
            "relh": {"max": 100.0, "min": 72.56},
            "drct": {"max": 180.0, "min": 0.0},
            "wspeedkm": {"max": 9.26, "min": 1.852},
            "pressure": {"max": 101490.1083, "min": 101016.0137},
            "vsbykm": {"max": 2.9933724, "min": 0.9012304},
            "feelc": {"max": 20.0, "min": 14.0}
        }
    },
    {
        "subgroup": 26,
        "conditions": {
            "tmpc": {"max": 19.0, "min": 12.0},
            "dwpc": {"max": 17.0, "min": 8.0},
            "relh": {"max": 100.0, "min": 63.6},
            "drct": {"max": 330.0, "min": 160.0},
            "wspeedkm": {"max": 14.816, "min": 3.704},
            "pressure": {"max": 101490.1083, "min": 100914.422},
            "vsbykm": {"max": 4.0072566, "min": 1.9955816},
            "feelc": {"max": 19.0, "min": 12.0}
        }
    },
    {
        "subgroup": 27,
        "conditions": {
            "tmpc": {"max": 29.0, "min": 23.0},
            "dwpc": {"max": 20.0, "min": 13.0},
            "relh": {"max": 69.33, "min": 47.25},
            "drct": {"max": 350.0, "min": 140.0},
            "wspeedkm": {"max": 11.112, "min": 3.704},
            "pressure": {"max": 101794.8834, "min": 101286.9249},
            "vsbykm": {"max": 2.9933724, "min": 1.207005},
            "feelc": {"max": 30.27777778, "min": 23.0}
        }
    },
    {
        "subgroup": 28,
        "conditions": {
            "tmpc": {"max": 16.0, "min": 10.0},
            "dwpc": {"max": 13.5, "min": 7.0},
            "relh": {"max": 93.65, "min": 63.15},
            "drct": {"max": 360.0, "min": 213.3333333},
            "wspeedkm": {"max": 14.816, "min": 3.704},
            "pressure": {"max": 102201.2502, "min": 101693.2917},
            "vsbykm": {"max": 2.9933724, "min": 0.9977908},
            "feelc": {"max": 16.0, "min": 10.0}
        }
    },
    {
        "subgroup": 29,
        "conditions": {
            "tmpc": {"max": 13.0, "min": 8.0},
            "dwpc": {"max": 12.0, "min": 6.0},
            "relh": {"max": 100.0, "min": 71.64},
            "drct": {"max": 206.6666667, "min": 29.0},
            "wspeedkm": {"max": 11.112, "min": 1.852},
            "pressure": {"max": 101896.4751, "min": 101286.9249},
            "vsbykm": {"max": 1.4966862, "min": 0.0321868},
            "feelc": {"max": 13.0, "min": 7.572222222}
        }
    },
    {
        "subgroup": 30,
        "conditions": {
            "tmpc": {"max": 25.0, "min": 18.0},
            "dwpc": {"max": 16.0, "min": 10.0},
            "relh": {"max": 72.74, "min": 43.69},
            "drct": {"max": 260.0, "min": 0.0},
            "wspeedkm": {"max": 12.964, "min": 3.704},
            "pressure": {"max": 101896.4751, "min": 101185.3332},
            "vsbykm": {"max": 2.494477, "min": 0.6920162},
            "feelc": {"max": 25.0, "min": 18.0}
        }
    },

    {
        "subgroup": 31,
        "conditions": {
            "tmpc": {"max": 18.0, "min": 13.0},
            "dwpc": {"max": 16.0, "min": 11.0},
            "relh": {"max": 100.0, "min": 82.25},
            "drct": {"max": 180.0, "min": 10.0},
            "wspeedkm": {"max": 14.816, "min": 6.173333333},
            "pressure": {"max": 101930.339, "min": 101185.3332},
            "vsbykm": {"max": 1.9955816, "min": 0.3540548},
            "feelc": {"max": 18.0, "min": 13.0}
        }
    },
    {
        "subgroup": 32,
        "conditions": {
            "tmpc": {"max": 25.0, "min": 17.0},
            "dwpc": {"max": 17.0, "min": 10.0},
            "relh": {"max": 77.9, "min": 44.25},
            "drct": {"max": 350.0, "min": 130.0},
            "wspeedkm": {"max": 16.668, "min": 7.408},
            "pressure": {"max": 101896.4751, "min": 101236.129},
            "vsbykm": {"max": 4.506152, "min": 2.7439247},
            "feelc": {"max": 25.0, "min": 17.0}
        }
    },
    {
        "subgroup": 33,
        "conditions": {
            "tmpc": {"max": 18.0, "min": 11.0},
            "dwpc": {"max": 15.5, "min": 9.0},
            "relh": {"max": 100.0, "min": 76.82},
            "drct": {"max": 340.0, "min": 260.0},
            "wspeedkm": {"max": 14.816, "min": 9.26},
            "pressure": {"max": 101998.0668, "min": 101286.9249},
            "vsbykm": {"max": 2.494477, "min": 0.0965604},
            "feelc": {"max": 18.0, "min": 11.0}
        }
    },
    {
        "subgroup": 34,
        "conditions": {
            "tmpc": {"max": 23.0, "min": 16.0},
            "dwpc": {"max": 18.0, "min": 10.0},
            "relh": {"max": 82.86, "min": 56.13},
            "drct": {"max": 340.0, "min": 115.0},
            "wspeedkm": {"max": 9.26, "min": 1.852},
            "pressure": {"max": 101794.8834, "min": 101286.9249},
            "vsbykm": {"max": 4.506152, "min": 2.494477},
            "feelc": {"max": 23.0, "min": 16.0}
        }
    },
    {
        "subgroup": 35,
        "conditions": {
            "tmpc": {"max": 20.0, "min": 15.0},
            "dwpc": {"max": 18.0, "min": 12.0},
            "relh": {"max": 93.92, "min": 72.38},
            "drct": {"max": 160.0, "min": 0.0},
            "wspeedkm": {"max": 5.556, "min": 0.0},
            "pressure": {"max": 102099.6585, "min": 101591.7},
            "vsbykm": {"max": 1.6012933, "min": 0.1448406},
            "feelc": {"max": 20.0, "min": 15.0}
        }
    },
    {
        "subgroup": 36,
        "conditions": {
            "tmpc": {"max": 23.0, "min": 17.0},
            "dwpc": {"max": 19.0, "min": 13.0},
            "relh": {"max": 93.88, "min": 64.26},
            "drct": {"max": 80.0, "min": 0.0},
            "wspeedkm": {"max": 3.704, "min": 0.0},
            "pressure": {"max": 101998.0668, "min": 101388.5166},
            "vsbykm": {"max": 3.4922678, "min": 1.8024608},
            "feelc": {"max": 23.0, "min": 17.0}
        }
    },
    {
        "subgroup": 37,
        "conditions": {
            "tmpc": {"max": 16.0, "min": 11.0},
            "dwpc": {"max": 15.0, "min": 10.0},
            "relh": {"max": 100.0, "min": 82.12},
            "drct": {"max": 90.0, "min": 0.0},
            "wspeedkm": {"max": 3.704, "min": 0.0},
            "pressure": {"max": 101439.3125, "min": 101016.0137},
            "vsbykm": {"max": 1.4966862, "min": 0.0482802},
            "feelc": {"max": 16.0, "min": 11.0}
        }
    },
    {
        "subgroup": 38,
        "conditions": {
            "tmpc": {"max": 28.0, "min": 18.92857143},
            "dwpc": {"max": 14.11111111, "min": 7.0},
            "relh": {"max": 56.88, "min": 36.22},
            "drct": {"max": 340.0, "min": 113.3333333},
            "wspeedkm": {"max": 11.112, "min": 3.704},
            "pressure": {"max": 101693.2917, "min": 101016.0137},
            "vsbykm": {"max": 4.506152, "min": 2.9933724},
            "feelc": {"max": 27.63888889, "min": 18.92857143}
        }
    },
    {
        "subgroup": 39,
        "conditions": {
            "tmpc": {"max": 20.0, "min": 13.0},
            "dwpc": {"max": 12.0, "min": 6.0},
            "relh": {"max": 72.01, "min": 42.57},
            "drct": {"max": 350.0, "min": 230.0},
            "wspeedkm": {"max": 14.816, "min": 3.704},
            "pressure": {"max": 102099.6585, "min": 101388.5166},
            "vsbykm": {"max": 4.0072566, "min": 1.4966862},
            "feelc": {"max": 20.0, "min": 13.0}
        }
    },
    {
        "subgroup": 40,
        "conditions": {
            "tmpc": {"max": 25.0, "min": 17.0},
            "dwpc": {"max": 13.5, "min": 7.0},
            "relh": {"max": 56.63, "min": 38.46},
            "drct": {"max": 350.0, "min": 120.0},
            "wspeedkm": {"max": 13.89, "min": 3.704},
            "pressure": {"max": 101794.8834, "min": 101083.7415},
            "vsbykm": {"max": 2.9933724, "min": 0.9977908},
            "feelc": {"max": 25.0, "min": 17.0}
        }
    },
    {
        "subgroup": 41,
        "conditions": {
            "tmpc": {"max": 17.0, "min": 10.0},
            "dwpc": {"max": 15.0, "min": 9.0},
            "relh": {"max": 100.0, "min": 76.82},
            "drct": {"max": 207.1428571, "min": 0.0},
            "wspeedkm": {"max": 11.112, "min": 2.469333333},
            "pressure": {"max": 101388.5166, "min": 100711.2386},
            "vsbykm": {"max": 1.9955816, "min": 0.0482802},
            "feelc": {"max": 17.0, "min": 10.0}
        }
    },
    {
        "subgroup": 42,
        "conditions": {
            "tmpc": {"max": 22.33333333, "min": 16.0},
            "dwpc": {"max": 19.66666667, "min": 13.0},
            "relh": {"max": 93.97, "min": 64.04},
            "drct": {"max": 200.0, "min": 0.0},
            "wspeedkm": {"max": 12.964, "min": 3.704},
            "pressure": {"max": 101896.4751, "min": 101185.3332},
            "vsbykm": {"max": 4.040516293, "min": 2.2450293},
            "feelc": {"max": 22.33333333, "min": 16.0}
        }
    },
    {
        "subgroup": 43,
        "conditions": {
            "tmpc": {"max": 30.0, "min": 23.0},
            "dwpc": {"max": 16.0, "min": 10.0},
            "relh": {"max": 54.05, "min": 32.46},
            "drct": {"max": 243.3333333, "min": 0.0},
            "wspeedkm": {"max": 11.112, "min": 0.0},
            "pressure": {"max": 101794.8834, "min": 101185.3332},
            "vsbykm": {"max": 3.4922678, "min": 1.207005},
            "feelc": {"max": 30.02777778, "min": 23.0}
        }
    },
    {
        "subgroup": 44,
        "conditions": {
            "tmpc": {"max": 25.0, "min": 18.0},
            "dwpc": {"max": 18.0, "min": 11.0},
            "relh": {"max": 78.04, "min": 53.03},
            "drct": {"max": 320.0, "min": 90.0},
            "wspeedkm": {"max": 18.52, "min": 7.408},
            "pressure": {"max": 101388.5166, "min": 100812.8303},
            "vsbykm": {"max": 3.071363492, "min": 1.8024608},
            "feelc": {"max": 25.0, "min": 18.0}
        }
    },
    {
        "subgroup": 45,
        "conditions": {
            "tmpc": {"max": 16.0, "min": 11.0},
            "dwpc": {"max": 14.0, "min": 9.0},
            "relh": {"max": 100.0, "min": 76.82},
            "drct": {"max": 148.5714286, "min": 0.0},
            "wspeedkm": {"max": 3.704, "min": 0.0},
            "pressure": {"max": 101388.5166, "min": 100812.8303},
            "vsbykm": {"max": 2.9933724, "min": 1.4966862},
            "feelc": {"max": 16.0, "min": 11.0}
        }
    },
    {
        "subgroup": 46,
        "conditions": {
            "tmpc": {"max": 15.0, "min": 11.0},
            "dwpc": {"max": 13.0, "min": 9.0},
            "relh": {"max": 100.0, "min": 76.82},
            "drct": {"max": 41.25, "min": 0.0},
            "wspeedkm": {"max": 1.852, "min": 0.0},
            "pressure": {"max": 101794.8834, "min": 101388.5166},
            "vsbykm": {"max": 2.494477, "min": 0.6920162},
            "feelc": {"max": 15.0, "min": 11.0}
        }
    },
    {
        "subgroup": 47,
        "conditions": {
            "tmpc": {"max": 24.0, "min": 18.0},
            "dwpc": {"max": 20.0, "min": 14.0},
            "relh": {"max": 94.01, "min": 68.55},
            "drct": {"max": 350.0, "min": 150.0},
            "wspeedkm": {"max": 13.89, "min": 3.704},
            "pressure": {"max": 101744.0876, "min": 101083.7415},
            "vsbykm": {"max": 1.9955816, "min": 0.5954558},
            "feelc": {"max": 24.0, "min": 18.0}
        }
    },
    {
        "subgroup": 48,
        "conditions": {
            "tmpc": {"max": 18.5, "min": 14.0},
            "dwpc": {"max": 17.0, "min": 12.0},
            "relh": {"max": 100.0, "min": 80.11},
            "drct": {"max": 62.5, "min": 0.0},
            "wspeedkm": {"max": 3.704, "min": 0.0},
            "pressure": {"max": 101794.8834, "min": 101286.9249},
            "vsbykm": {"max": 2.9933724, "min": 1.207005},
            "feelc": {"max": 18.5, "min": 14.0}
        }
    },
    {
        "subgroup": 49,
        "conditions": {
            "tmpc": {"max": 14.0, "min": 8.0},
            "dwpc": {"max": 12.0, "min": 6.0},
            "relh": {"max": 100.0, "min": 71.64},
            "drct": {"max": 155.0, "min": 0.0},
            "wspeedkm": {"max": 7.408, "min": 0.0},
            "pressure": {"max": 102404.4336, "min": 101896.4751},
            "vsbykm": {"max": 1.4966862, "min": 0.0482802},
            "feelc": {"max": 14.0, "min": 7.966666667}
        }
    },
    {
        "subgroup": 50,
        "conditions": {
            "tmpc": {"max": 27.0, "min": 21.0},
            "dwpc": {"max": 23.0, "min": 15.0},
            "relh": {"max": 83.55, "min": 57.6},
            "drct": {"max": 350.0, "min": 133.3333333},
            "wspeedkm": {"max": 9.26, "min": 3.704},
            "pressure": {"max": 101388.5166, "min": 100812.8303},
            "vsbykm": {"max": 2.9933724, "min": 1.207005},
            "feelc": {"max": 28.19444444, "min": 21.0}
        }
    },
    {
        "subgroup": 51,
        "conditions": {
            "tmpc": {"max": 25.0, "min": 17.0},
            "dwpc": {"max": 13.0, "min": 6.0},
            "relh": {"max": 67.95, "min": 33.57},
            "drct": {"max": 340.0, "min": 110.0},
            "wspeedkm": {"max": 20.372, "min": 11.112},
            "pressure": {"max": 101794.8834, "min": 101083.7415},
            "vsbykm": {"max": 4.506152, "min": 1.3518456},
            "feelc": {"max": 25.0, "min": 17.0}
        }
    },
    {
        "subgroup": 52,
        "conditions": {
            "tmpc": {"max": 19.0, "min": 12.75},
            "dwpc": {"max": 16.0, "min": 10.0},
            "relh": {"max": 93.83, "min": 72.01},
            "drct": {"max": 100.0, "min": 0.0},
            "wspeedkm": {"max": 5.556, "min": 0.0},
            "pressure": {"max": 102201.2502, "min": 101693.2917},
            "vsbykm": {"max": 2.9933724, "min": 0.9977908},
            "feelc": {"max": 19.0, "min": 12.75}
        }
    },
    {
        "subgroup": 53,
        "conditions": {
            "tmpc": {"max": 20.0, "min": 15.0},
            "dwpc": {"max": 18.0, "min": 13.0},
            "relh": {"max": 100.0, "min": 77.45},
            "drct": {"max": 220.0, "min": 0.0},
            "wspeedkm": {"max": 12.964, "min": 3.704},
            "pressure": {"max": 102099.6585, "min": 101490.1083},
            "vsbykm": {"max": 2.9933724, "min": 1.207005},
            "feelc": {"max": 20.0, "min": 15.0}
        }
    },
    {
        "subgroup": 54,
        "conditions": {
            "tmpc": {"max": 25.0, "min": 19.0},
            "dwpc": {"max": 19.0, "min": 14.0},
            "relh": {"max": 82.98, "min": 60.67},
            "drct": {"max": 80.0, "min": 0.0},
            "wspeedkm": {"max": 5.556, "min": 0.0},
            "pressure": {"max": 101591.7, "min": 101083.7415},
            "vsbykm": {"max": 2.494477, "min": 0.80467},
            "feelc": {"max": 25.0, "min": 19.0}
        }
    },
    {
        "subgroup": 55,
        "conditions": {
            "tmpc": {"max": 26.0, "min": 19.0},
            "dwpc": {"max": 20.0, "min": 12.0},
            "relh": {"max": 83.09, "min": 50.8},
            "drct": {"max": 340.0, "min": 135.0},
            "wspeedkm": {"max": 12.964, "min": 3.704},
            "pressure": {"max": 101286.9249, "min": 100711.2386},
            "vsbykm": {"max": 4.450719178, "min": 2.7439247},
            "feelc": {"max": 26.0, "min": 19.0}
        }
    },
    {
        "subgroup": 56,
        "conditions": {
            "tmpc": {"max": 25.0, "min": 19.0},
            "dwpc": {"max": 19.0, "min": 13.5},
            "relh": {"max": 83.09, "min": 55.55},
            "drct": {"max": 44.73684211, "min": 0.0},
            "wspeedkm": {"max": 3.704, "min": 0.0},
            "pressure": {"max": 101998.0668, "min": 101591.7},
            "vsbykm": {"max": 2.494477, "min": 0.80467},
            "feelc": {"max": 25.0, "min": 19.0}
        }
    },
    {
        "subgroup": 57,
        "conditions": {
            "tmpc": {"max": 30.0, "min": 24.0},
            "dwpc": {"max": 18.0, "min": 11.0},
            "relh": {"max": 61.36, "min": 39.86},
            "drct": {"max": 170.0, "min": 0.0},
            "wspeedkm": {"max": 7.408, "min": 0.0},
            "pressure": {"max": 101388.5166, "min": 100914.422},
            "vsbykm": {"max": 3.4922678, "min": 1.9955816},
            "feelc": {"max": 30.82777778, "min": 24.0}
        }
    },
    {
        "subgroup": 58,
        "conditions": {
            "tmpc": {"max": 13.0, "min": 7.0},
            "dwpc": {"max": 11.0, "min": 5.0},
            "relh": {"max": 100.0, "min": 66.48},
            "drct": {"max": 160.0, "min": 0.0},
            "wspeedkm": {"max": 7.408, "min": 0.0},
            "pressure": {"max": 102150.4543, "min": 101693.2917},
            "vsbykm": {"max": 2.494477, "min": 0.9977908},
            "feelc": {"max": 13.0, "min": 7.0}
        }
    },
    {
        "subgroup": 59,
        "conditions": {
            "tmpc": {"max": 22.5, "min": 15.5},
            "dwpc": {"max": 15.0, "min": 8.0},
            "relh": {"max": 77.45, "min": 49.37},
            "drct": {"max": 360.0, "min": 130.0},
            "wspeedkm": {"max": 9.26, "min": 1.852},
            "pressure": {"max": 101693.2917, "min": 101083.7415},
            "vsbykm": {"max": 2.9933724, "min": 0.9977908},
            "feelc": {"max": 22.5, "min": 15.5}
        }
    },
    {
        "subgroup": 60,
        "conditions": {
            "tmpc": {"max": 25.0, "min": 18.0},
            "dwpc": {"max": 15.0, "min": 9.0},
            "relh": {"max": 64.04, "min": 40.85},
            "drct": {"max": 165.0, "min": 0.0},
            "wspeedkm": {"max": 11.112, "min": 0.0},
            "pressure": {"max": 101998.0668, "min": 101388.5166},
            "vsbykm": {"max": 4.0072566, "min": 1.9955816},
            "feelc": {"max": 25.0, "min": 18.0}
        }
    },

    {
        "subgroup": 61,
        "conditions": {
            "tmpc": {"max": 19.0, "min": 14.0},
            "dwpc": {"max": 18.0, "min": 12.85714286},
            "relh": {"max": 100.0, "min": 77.29},
            "drct": {"max": 217.5, "min": 0.0},
            "wspeedkm": {"max": 7.408, "min": 1.852},
            "pressure": {"max": 101794.8834, "min": 101185.3332},
            "vsbykm": {"max": 1.6495735, "min": 0.0965604},
            "feelc": {"max": 19.0, "min": 14.0}
        }
    },
    {
        "subgroup": 62,
        "conditions": {
            "tmpc": {"max": 22.0, "min": 15.0},
            "dwpc": {"max": 16.0, "min": 9.0},
            "relh": {"max": 88.09, "min": 55.88},
            "drct": {"max": 350.0, "min": 130.0},
            "wspeedkm": {"max": 18.52, "min": 8.334},
            "pressure": {"max": 101896.4751, "min": 101185.3332},
            "vsbykm": {"max": 2.494477, "min": 0.80467},
            "feelc": {"max": 22.0, "min": 15.0}
        }
    },
    {
        "subgroup": 63,
        "conditions": {
            "tmpc": {"max": 24.26666667, "min": 18.0},
            "dwpc": {"max": 16.5, "min": 9.0},
            "relh": {"max": 72.92, "min": 46.43},
            "drct": {"max": 180.0, "min": 0.0},
            "wspeedkm": {"max": 5.556, "min": 0.0},
            "pressure": {"max": 101591.7, "min": 100914.422},
            "vsbykm": {"max": 4.0072566, "min": 2.9933724},
            "feelc": {"max": 24.23185185, "min": 18.0}
        }
    },
    {
        "subgroup": 64,
        "conditions": {
            "tmpc": {"max": 30.0, "min": 25.0},
            "dwpc": {"max": 23.0, "min": 18.0},
            "relh": {"max": 78.76, "min": 54.55},
            "drct": {"max": 240.0, "min": 0.0},
            "wspeedkm": {"max": 9.26, "min": 0.0},
            "pressure": {"max": 101693.2917, "min": 101016.0137},
            "vsbykm": {"max": 3.4922678, "min": 1.207005},
            "feelc": {"max": 32.0, "min": 25.0}
        }
    },
    {
        "subgroup": 65,
        "conditions": {
            "tmpc": {"max": 17.0, "min": 13.0},
            "dwpc": {"max": 16.0, "min": 11.5},
            "relh": {"max": 100.0, "min": 77.14},
            "drct": {"max": 360.0, "min": 214.2857143},
            "wspeedkm": {"max": 11.112, "min": 3.704},
            "pressure": {"max": 101591.7, "min": 101016.0137},
            "vsbykm": {"max": 1.9955816, "min": 0.402335},
            "feelc": {"max": 17.0, "min": 13.0}
        }
    },
    {
        "subgroup": 66,
        "conditions": {
            "tmpc": {"max": 22.0, "min": 16.0},
            "dwpc": {"max": 18.0, "min": 13.0},
            "relh": {"max": 100.0, "min": 68.55},
            "drct": {"max": 280.0, "min": 10.0},
            "wspeedkm": {"max": 18.52, "min": 9.26},
            "pressure": {"max": 101794.8834, "min": 101083.7415},
            "vsbykm": {"max": 3.4922678, "min": 0.9977908},
            "feelc": {"max": 22.0, "min": 16.0}
        }
    },
    {
        "subgroup": 67,
        "conditions": {
            "tmpc": {"max": 26.0, "min": 20.0},
            "dwpc": {"max": 21.0, "min": 16.0},
            "relh": {"max": 88.34, "min": 61.13},
            "drct": {"max": 180.0, "min": 0.0},
            "wspeedkm": {"max": 5.556, "min": 0.0},
            "pressure": {"max": 101705.2437, "min": 100914.422},
            "vsbykm": {"max": 4.05714614, "min": 2.9933724},
            "feelc": {"max": 26.0, "min": 20.0}
        }
    },
    {
        "subgroup": 68,
        "conditions": {
            "tmpc": {"max": 22.0, "min": 15.0},
            "dwpc": {"max": 17.0, "min": 11.5},
            "relh": {"max": 93.83, "min": 63.82},
            "drct": {"max": 360.0, "min": 130.0},
            "wspeedkm": {"max": 11.112, "min": 3.704},
            "pressure": {"max": 102302.8419, "min": 101693.2917},
            "vsbykm": {"max": 2.9933724, "min": 0.4988954},
            "feelc": {"max": 22.0, "min": 15.0}
        }
    },
    {
        "subgroup": 69,
        "conditions": {
            "tmpc": {"max": 30.0, "min": 22.375},
            "dwpc": {"max": 16.0, "min": 9.0},
            "relh": {"max": 53.8, "min": 32.73},
            "drct": {"max": 350.0, "min": 100.0},
            "wspeedkm": {"max": 18.52, "min": 7.408},
            "pressure": {"max": 101591.7, "min": 100914.422},
            "vsbykm": {"max": 4.0072566, "min": 2.494477},
            "feelc": {"max": 29.70555556, "min": 22.375}
        }
    },
    {
        "subgroup": 70,
        "conditions": {
            "tmpc": {"max": 10.0, "min": 6.0},
            "dwpc": {"max": 8.5, "min": 4.0},
            "relh": {"max": 100.0, "min": 71.07},
            "drct": {"max": 340.0, "min": 90.0},
            "wspeedkm": {"max": 11.112, "min": 3.704},
            "pressure": {"max": 102302.8419, "min": 101693.2917},
            "vsbykm": {"max": 1.4966862, "min": 0.0482802},
            "feelc": {"max": 10.0, "min": 5.005555556}
        }
    },

    {
        "subgroup": 71,
        "conditions": {
            "tmpc": {"max": 16.0, "min": 10.0},
            "dwpc": {"max": 13.0, "min": 8.0},
            "relh": {"max": 100.0, "min": 76.66},
            "drct": {"max": 340.0, "min": 156.0},
            "wspeedkm": {"max": 11.112, "min": 3.704},
            "pressure": {"max": 101642.4959, "min": 101016.0137},
            "vsbykm": {"max": 2.9933724, "min": 1.4001258},
            "feelc": {"max": 16.0, "min": 9.594444444}
        }
    },
    {
        "subgroup": 72,
        "conditions": {
            "tmpc": {"max": 16.0, "min": 12.0},
            "dwpc": {"max": 15.0, "min": 10.0},
            "relh": {"max": 100.0, "min": 76.82},
            "drct": {"max": 25.71428571, "min": 0.0},
            "wspeedkm": {"max": 3.704, "min": 0.0},
            "pressure": {"max": 102099.6585, "min": 101642.4959},
            "vsbykm": {"max": 1.4966862, "min": 0.0482802},
            "feelc": {"max": 16.0, "min": 12.0}
        }
    },
    {
        "subgroup": 73,
        "conditions": {
            "tmpc": {"max": 22.0, "min": 17.0},
            "dwpc": {"max": 20.0, "min": 14.5},
            "relh": {"max": 100.0, "min": 78.175},
            "drct": {"max": 135.0, "min": 0.0},
            "wspeedkm": {"max": 5.556, "min": 0.0},
            "pressure": {"max": 101794.8834, "min": 101286.9249},
            "vsbykm": {"max": 1.9955816, "min": 0.3057746},
            "feelc": {"max": 22.0, "min": 17.0}
        }
    },
    {
        "subgroup": 74,
        "conditions": {
            "tmpc": {"max": 20.0, "min": 14.0},
            "dwpc": {"max": 14.5, "min": 8.0},
            "relh": {"max": 82.5, "min": 59.5},
            "drct": {"max": 145.0, "min": 0.0},
            "wspeedkm": {"max": 5.556, "min": 0.0},
            "pressure": {"max": 101794.8834, "min": 101185.3332},
            "vsbykm": {"max": 2.494477, "min": 0.9977908},
            "feelc": {"max": 20.0, "min": 14.0}
        }
    },
    {
        "subgroup": 75,
        "conditions": {
            "tmpc": {"max": 23.0, "min": 16.0},
            "dwpc": {"max": 17.0, "min": 9.0},
            "relh": {"max": 82.62, "min": 52.77},
            "drct": {"max": 202.5, "min": 0.0},
            "wspeedkm": {"max": 9.26, "min": 0.0},
            "pressure": {"max": 102302.8419, "min": 101693.2917},
            "vsbykm": {"max": 3.4922678, "min": 0.80467},
            "feelc": {"max": 23.0, "min": 16.0}
        }
    },
    {
        "subgroup": 76,
        "conditions": {
            "tmpc": {"max": 26.0, "min": 21.0},
            "dwpc": {"max": 23.0, "min": 18.0},
            "relh": {"max": 94.1, "min": 69.14},
            "drct": {"max": 192.8571429, "min": 0.0},
            "wspeedkm": {"max": 6.482, "min": 0.0},
            "pressure": {"max": 101794.8834, "min": 101185.3332},
            "vsbykm": {"max": 2.494477, "min": 0.9977908},
            "feelc": {"max": 26.0, "min": 21.0}
        }
    },
    {
        "subgroup": 77,
        "conditions": {
            "tmpc": {"max": 20.0, "min": 15.0},
            "dwpc": {"max": 18.0, "min": 12.0},
            "relh": {"max": 93.92, "min": 70.365},
            "drct": {"max": 72.5, "min": 0.0},
            "wspeedkm": {"max": 7.408, "min": 0.0},
            "pressure": {"max": 101286.9249, "min": 100812.8303},
            "vsbykm": {"max": 3.4922678, "min": 1.5932466},
            "feelc": {"max": 20.0, "min": 15.0}
        }
    },
    {
        "subgroup": 78,
        "conditions": {
            "tmpc": {"max": 12.5, "min": 7.0},
            "dwpc": {"max": 10.0, "min": 5.0},
            "relh": {"max": 100.0, "min": 71.45},
            "drct": {"max": 350.0, "min": 135.0},
            "wspeedkm": {"max": 11.112, "min": 3.704},
            "pressure": {"max": 102099.6585, "min": 101490.1083},
            "vsbykm": {"max": 2.9933724, "min": 0.9977908},
            "feelc": {"max": 12.5, "min": 6.161111111}
        }
    },
    {
        "subgroup": 79,
        "conditions": {
            "tmpc": {"max": 13.0, "min": 9.0},
            "dwpc": {"max": 11.0, "min": 7.0},
            "relh": {"max": 100.0, "min": 76.34},
            "drct": {"max": 37.5, "min": 0.0},
            "wspeedkm": {"max": 3.704, "min": 0.0},
            "pressure": {"max": 101896.4751, "min": 101591.7},
            "vsbykm": {"max": 1.4966862, "min": 0.0482802},
            "feelc": {"max": 13.0, "min": 9.0}
        }
    },
    {
        "subgroup": 80,
        "conditions": {
            "tmpc": {"max": 25.0, "min": 17.0},
            "dwpc": {"max": 12.5, "min": 6.0},
            "relh": {"max": 59.97, "min": 34.755},
            "drct": {"max": 350.0, "min": 100.0},
            "wspeedkm": {"max": 11.112, "min": 2.778},
            "pressure": {"max": 102048.8627, "min": 101286.9249},
            "vsbykm": {"max": 4.0072566, "min": 2.494477},
            "feelc": {"max": 25.0, "min": 17.0}
        }
    },

    {
        "subgroup": 81,
        "conditions": {
            "tmpc": {"max": 18.0, "min": 13.0},
            "dwpc": {"max": 15.0, "min": 10.0},
            "relh": {"max": 93.79, "min": 72.38},
            "drct": {"max": 360.0, "min": 125.0},
            "wspeedkm": {"max": 11.112, "min": 3.704},
            "pressure": {"max": 101998.0668, "min": 101388.5166},
            "vsbykm": {"max": 4.0072566, "min": 1.9955816},
            "feelc": {"max": 18.0, "min": 13.0}
        }
    },
    {
        "subgroup": 82,
        "conditions": {
            "tmpc": {"max": 21.0, "min": 16.0},
            "dwpc": {"max": 19.0, "min": 14.0},
            "relh": {"max": 100.0, "min": 73.09},
            "drct": {"max": 360.0, "min": 170.0},
            "wspeedkm": {"max": 12.501, "min": 3.704},
            "pressure": {"max": 101794.8834, "min": 101388.5166},
            "vsbykm": {"max": 2.9933724, "min": 0.9977908},
            "feelc": {"max": 21.0, "min": 16.0}
        }
    },
    {
        "subgroup": 83,
        "conditions": {
            "tmpc": {"max": 28.0, "min": 21.0},
            "dwpc": {"max": 20.5, "min": 14.0},
            "relh": {"max": 78.19, "min": 50.95},
            "drct": {"max": 224.0, "min": 0.0},
            "wspeedkm": {"max": 9.26, "min": 0.0},
            "pressure": {"max": 101998.0668, "min": 101490.1083},
            "vsbykm": {"max": 3.5003145, "min": 1.4966862},
            "feelc": {"max": 28.56111111, "min": 21.0}
        }
    },
    {
        "subgroup": 84,
        "conditions": {
            "tmpc": {"max": 25.33333333, "min": 20.0},
            "dwpc": {"max": 21.0, "min": 14.0},
            "relh": {"max": 83.32, "min": 60.67},
            "drct": {"max": 94.54545455, "min": 0.0},
            "wspeedkm": {"max": 3.704, "min": 0.0},
            "pressure": {"max": 101388.5166, "min": 100711.2386},
            "vsbykm": {"max": 3.4922678, "min": 1.207005},
            "feelc": {"max": 25.33333333, "min": 20.0}
        }
    },
    {
        "subgroup": 85,
        "conditions": {
            "tmpc": {"max": 13.0, "min": 8.0},
            "dwpc": {"max": 12.0, "min": 7.0},
            "relh": {"max": 100.0, "min": 71.45},
            "drct": {"max": 130.0, "min": 0.0},
            "wspeedkm": {"max": 5.556, "min": 0.0},
            "pressure": {"max": 101540.9041, "min": 101016.0137},
            "vsbykm": {"max": 1.207005, "min": 0.0482802},
            "feelc": {"max": 13.0, "min": 8.0}
        }
    },
    {
        "subgroup": 86,
        "conditions": {
            "tmpc": {"max": 29.0, "min": 22.0},
            "dwpc": {"max": 18.0, "min": 10.0},
            "relh": {"max": 64.91, "min": 39.02},
            "drct": {"max": 340.0, "min": 110.0},
            "wspeedkm": {"max": 18.52, "min": 9.26},
            "pressure": {"max": 101794.8834, "min": 101083.7415},
            "vsbykm": {"max": 2.9933724, "min": 1.4966862},
            "feelc": {"max": 29.83888889, "min": 22.0}
        }
    },
    {
        "subgroup": 87,
        "conditions": {
            "tmpc": {"max": 13.0, "min": 8.0},
            "dwpc": {"max": 11.0, "min": 7.0},
            "relh": {"max": 100.0, "min": 76.34},
            "drct": {"max": 150.0, "min": 0.0},
            "wspeedkm": {"max": 3.704, "min": 0.0},
            "pressure": {"max": 101693.2917, "min": 101185.3332},
            "vsbykm": {"max": 2.9933724, "min": 1.207005},
            "feelc": {"max": 13.0, "min": 8.0}
        }
    },
    {
        "subgroup": 88,
        "conditions": {
            "tmpc": {"max": 28.0, "min": 21.0},
            "dwpc": {"max": 20.0, "min": 13.0},
            "relh": {"max": 73.61, "min": 47.25},
            "drct": {"max": 320.0, "min": 20.0},
            "wspeedkm": {"max": 15.5105, "min": 3.704},
            "pressure": {"max": 101957.4301, "min": 101083.7415},
            "vsbykm": {"max": 4.506152, "min": 2.494477},
            "feelc": {"max": 28.87777778, "min": 21.0}
        }
    },
    
])

# Define a function to check if a point satisfies a rule
def point_satisfies_rule(point, rule):
    conditions = rule["conditions"]
    for param, limits in conditions.items():
        if not (limits["min"] <= point[param] <= limits["max"]):
            return False
    return True

# Define a function to check which subgroup a point belongs to
def check_subgroup(point):
    for rule in rules:
        if point_satisfies_rule(point, rule):
            return rule["subgroup"]
    return None

data = pd.read_csv("test_set_colab.csv")  

numeric_attributes = ['tmpc', 'dwpc','relh', 'drct', 'wspeedkm','pressure','vsbykm', 'feelc']

points = data[numeric_attributes]
count=0
# Check which points do not satisfy the rules
for i, point in enumerate(points.to_dict(orient='records'), 1):
    subgroup = check_subgroup(point)
    if subgroup is None:
        count=count+1
        # print(f"Point {i}: Does not satisfy any rules")
print(count)

satisfy_list = []
for point in points.to_dict(orient='records'):
    subgroup = check_subgroup(point)
    satisfy_list.append("Yes" if subgroup is not None else "No")

# Add the 'satisfy' column to the DataFrame
data['satisfy'] = satisfy_list

# Save the modified DataFrame to a new CSV file
data.to_csv("test_set_colab_with_satisfy.csv", index=False)
print(count)
# Out:
# 1012
# 1012

# %%
import pandas as pd

# Read the modified DataFrame
data = pd.read_excel("FinalModel_PredictionResult_and_anomalies.xlsx")

# Filter the DataFrame to get rows where both 'satisfy' and 'misclassified' columns have value 'Yes'
both_yes_count = len(data[(data['satisfy'] == 'No') & (data['Misclassified'] == 'YES')])

print("Number of rows are ", both_yes_count)
# Out:
# Number of rows are  95
